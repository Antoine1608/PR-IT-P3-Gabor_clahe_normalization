# %%
from image_processor_module import ImageProcessor

# %%
photo = r"C:\Users\John\Desktop\KA-CL-P2-Ovarian_Cancer_Classification\image.jpg"

# %%
# Instancier la classe ImageProcessor avec le chemin de votre image
image_processor = ImageProcessor(photo)

# Appeler la méthode process_and_display pour appliquer les traitements et afficher les résultats
image_processor.process_and_display()

# %% [markdown]
# # lancer les tests

# %%
# %run image_processor_module.py
# Out:
# ================================================= test session starts =================================================
# platform win32 -- Python 3.9.13, pytest-7.4.3, pluggy-1.3.0
# rootdir: C:\Users\John\Desktop\KA-CL-P2-Ovarian_Cancer_Classification
# plugins: anyio-4.1.0
# collected 5 items
#
# image_processor_module.py .....                                                                                  [100%]
#
# ================================================== 5 passed in 1.36s ==================================================

# %%
# Appliquer l'amélioration du contraste (CLAHE) en niveaux de gris
img = image_processor.apply_clahe_grayscale()

# Afficher l'image
plt.imshow(img, cmap='gray')  # Spécifiez le cmap='gray' pour indiquer que c'est une image en niveaux de gris
plt.show()
